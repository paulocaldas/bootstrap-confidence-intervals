# %% [markdown]
# ### Bootstrap Sample

# %%
import pandas as pd
from src import bootstrapping as bs

# get your data
X = pd.read_csv('data_examples/GF-15_3h_treatment.csv', sep = ';')['DMSO'].dropna()

# bootstrap the distribution to get confidence intervals
CI = bs.bootstrapping(X)
# Out:
# mean = 0.255; conf. interval = (0.229, 0.283); resamples = 10000

# %% [markdown]
# <hr>
